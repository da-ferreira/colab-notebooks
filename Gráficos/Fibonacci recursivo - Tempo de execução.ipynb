# %%
import matplotlib.pyplot as plt
import time

# %%
def fibonacci(termo):
    if termo <= 1:
        return termo
    else:
        return fibonacci(termo - 1) + fibonacci(termo - 2)

# %%
termo = [x for x in range(0, 45, 1)]

"""
tempo = []

for enesimo in termo:
    t_inicio = time.time()
    valor = fibonacci(enesimo)
    t_final = time.time() - t_inicio

    tempo.append(t_final)
"""

tempo = [1.9073486328125e-06,    4.76837158203125e-07,   9.5367431640625e-07,
         7.152557373046875e-07,  1.430511474609375e-06,  1.9073486328125e-06,
         3.0994415283203125e-06, 4.5299530029296875e-06, 7.867813110351562e-06,
         1.2159347534179688e-05, 1.9788742065429688e-05, 3.170967102050781e-05,
         5.125999450683594e-05,  8.58306884765625e-05,   0.00013375282287597656,
         0.00022125244140625,    0.0003955364227294922,  0.0005705356597900391,
         0.0009326934814453125,  0.001573324203491211,   0.0026276111602783203,
         0.0042383670806884766,  0.0067369937896728516,  0.010933399200439453,
         0.017252683639526367,   0.029092073440551758,   0.04845070838928223,
         0.07680487632751465,    0.12716031074523926,    0.20081591606140137,
         0.3515172004699707,     0.5445208549499512,     0.879368782043457,
         1.4012742042541504,     2.2640280723571777,     3.679389715194702,
         5.984585285186768,      9.64408540725708,       15.585992574691772,
         25.232641458511353,     40.55220866203308,      66.74994277954102,
         106.08087277412415,     174.08291268348694,     285.3825492858887]

plt.figure(figsize=(10, 8))

plt.plot([x for x in termo], [y for y in tempo])

plt.xlabel("Termo de Fibonacci", size=18)
plt.ylabel("Tempo em segundos", size=18)

plt.grid()
plt.show()
