# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a)

# %%
def velocidade_media(t_mais, t_menos):
    """ velocidade média = ((i+1 ^ 2 - 8i+1 + 18) - (i ^ 2 + 8i + 18)) / (ti + 1 - t) """
    return ((t_mais ** 2 - 8 * t_mais + 18) - (t_menos ** 2 - 8 * t_menos + 18)) / (t_mais - t_menos)

intervalos = [[3, 4], [3.5, 4], [4, 5], [4, 4.5]]
resultado = []

for intervalo in intervalos:
    resultado.append(velocidade_media(intervalo[1], intervalo[0]))

print(resultado)
# Out:
# [-1.0, -0.5, 1.0, 0.5]

# %% [markdown]
# b)

# %%
intervalos_t = [[4, x] for x in np.linspace(5, 4.0001, 50)]
resultado_t = []

for intervalo in intervalos_t:
    resultado_t.append(velocidade_media(intervalo[1], intervalo[0]))

print(resultado_t)
# Out:
# [1.0, 0.979593877551022, 0.9591877551020404, 0.9387816326530606, 0.9183755102040837, 0.8979693877551028, 0.8775632653061239, 0.8571571428571442, 0.8367510204081633, 0.8163448979591821, 0.7959387755102032, 0.7755326530612233, 0.7551265306122431, 0.7347204081632654, 0.7143142857142867, 0.6939081632653076, 0.6735020408163263, 0.6530959183673489, 0.6326897959183656, 0.6122836734693854, 0.5918775510204097, 0.5714714285714264, 0.5510653061224486, 0.5306591836734684, 0.5102530612244933, 0.48984693877551033, 0.46944081632653184, 0.44903469387755146, 0.42862857142856886, 0.4082224489795934, 0.38781632653061515, 0.3674102040816346, 0.34700408163265223, 0.32659795918367673, 0.3061918367346988, 0.2857857142857189, 0.26537959183673454, 0.24497346938776032, 0.22456734693876812, 0.2041612244898028, 0.1837551020408165, 0.16334897959184566, 0.1429428571428451, 0.12253673469388827, 0.10213061224489704, 0.08172448979593347, 0.06131836734696454, 0.04091224489798449, 0.02050612244896099, 0.00010000000827
# ...

# %% [markdown]
# c)

# %%
def funcao_s(t):
    return t ** 2 - 8 * t + 18

eixo_x = np.linspace(2.5, 5.5, 100)

plt.figure(figsize=(12, 10))

plt.title("Curva s(t) com retas secantes e suas inclinações (m)", fontsize=17)

plt.plot(eixo_x, [funcao_s(t) for t in eixo_x], 'b', label="Curva de s(t)")

plt.plot([3, 4], [funcao_s(3), funcao_s(4)], 'r', label="Reta secante (3, 4), m = -1")          # [3, 4],   m = -1.0
plt.plot([3.5, 4], [funcao_s(3.5), funcao_s(4)], 'g', label="Reta secante (3.5, 4), m = -0.5")  # [3.5, 4], m = -0.5
plt.plot([4, 5], [funcao_s(4), funcao_s(5)], 'c', label="Reta secante (4, 5), m = 1")           # [4, 5],   m = 1.0
plt.plot([4, 4.5], [funcao_s(4), funcao_s(4.5)], 'y', label="Reta secante (4, 4.5), m = 0.5")   # [4, 4.5], m = 0.5

plt.legend(loc=0, fontsize='x-large')
plt.grid()
plt.show()

# %% [markdown]
#
# d)
# Na curva s(t), sua equação da reta tangente é y = 2 ao ponto (4, 2) com sua
# inclinação (coeficiente angular) sendo 2t - 8 (nesse caso a inclinação da 0).

# %%
def funcao_s(t):
    return t ** 2 - 8 * t + 18

eixo_x = np.linspace(3, 5, 100)

plt.figure(figsize=(12, 10))

plt.title("Curva s(t) com retas secantes e suas inclinações (m)", fontsize=17)

plt.plot(eixo_x, [funcao_s(t) for t in eixo_x], 'b', label="Curva de s(t)")

plt.plot([3, 4], [funcao_s(3), funcao_s(4)], 'r', label="Reta secante (3, 4), m = -1")          # [3, 4],   m = -1.0
plt.plot([3.5, 4], [funcao_s(3.5), funcao_s(4)], 'g', label="Reta secante (3.5, 4), m = -0.5")  # [3.5, 4], m = -0.5
plt.plot([4, 5], [funcao_s(4), funcao_s(5)], 'c', label="Reta secante (4, 5), m = 1")           # [4, 5],   m = 1.0
plt.plot([4, 4.5], [funcao_s(4), funcao_s(4.5)], 'y', label="Reta secante (4, 4.5), m = 0.5")   # [4, 4.5], m = 0.5

reta_tangente = np.linspace(3.5, 4.5, 100)
plt.plot(reta_tangente, [2] * 100, 'k', label="Reta tangente ao ponto (4, 2)")
plt.plot(4, 2, 'ko', label="Ponto (4, 2)")

plt.legend(loc=0, fontsize='x-large')
plt.grid()
plt.show()
